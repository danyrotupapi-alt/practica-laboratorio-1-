# %% [markdown]
# <a href="https://colab.research.google.com/github/danyrotupapi-alt/practica-laboratorio-1-/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Funcion que retoma la suma de dos números
def sumar(a,b):
  return a + b
x = int(input("Ingrese el primer numero:"))
y = int(input("Ingrese el segundo numero:"))
print("La suma de los numeros es:",sumar(x,y))
# Out:
# Ingrese el primer numero:30
# Ingrese el segundo numero:29
# La suma de los numeros es: 59

# %%
def area_rectangulo(base, altura):
    """Calcula el área de un rectángulo."""
    area = base * altura
    return area

# Ejemplo de uso
base = float(input("Ingresa la base del rectángulo: "))
altura = float(input("Ingresa la altura del rectángulo: "))

print("El área del rectángulo es:", area_rectangulo(base, altura))
# Out:
# Ingresa la base del rectángulo: 12
# Ingresa la altura del rectángulo: 25
# El área del rectángulo es: 300.0
